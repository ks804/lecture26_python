# %%
filename = './sample.txt'

with open(filename) as f_read:
    content = f_read.read()
print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 filename = './sample.txt'
#       2
# ----> 3 with open(filename) as f_read:
#       4     content = f_read.read()
#       5 print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample.txt'

# %%
with open(filename) as f_read:
    content = f_read.read()
for line in lines:
    print(line.strip)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open(filename, encoding='utf-8') as f_read:
#       2     content = f_read.read()
#       3 for line in lines:
#       4     print(line.strip)
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample.txt'

# %%
with open(filename) as f_read:
    while True:
        line = f_read.readline()
        if line: print(line)
        else: break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open(filename) as f_read:
#       2     line = f_read.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample.txt'

# %%
fruits = ['사과', '토마토', '바나나']
outfile = 'fruits.txt'
with open(outfile, mode='w', encoding='utf-8') as f_write:
    f_write.write(fruits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 fruits = ['사과', '토마토', '바나나']
#       2 outfile = 'fruits.txt'
#       3 with open(outfile, mode='w', encoding='utf-8') as f_write:
# ----> 4     f_write.write(fruits)
#
# TypeError: write() argument must be str, not list

# %%
with open(outfile, mode='a', encoding='utf-8') as f_write:
    f_write.write('\n'.join(fruits))

# %%
with open(filename, mode='rb') as f_read:
    content = f_read.read()
print(content)
print(content.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 with open(filename, mode='rb') as f_read:
#       2     content = f_read.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: './sample.txt'
